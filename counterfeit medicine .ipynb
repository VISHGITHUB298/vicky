# %% [markdown]
# #  medicine sales

# %%
import numpy as np
import pandas as pd

# %%
train = pd.read_csv('counterfeit_train.csv')
test = pd.read_csv('counterfeit_test.csv')
train
test
# Out:
#      Medicine_ID  Counterfeit_Weight DistArea_ID  Active_Since  Medicine_MRP  \
# 0          HLZ81                 NaN     Area027          1983       85.5328
# 1          ECE94               13.45     Area045          2000      257.1460
# 2          SAD14                7.10     Area045          2000       98.1172
# 3          EQV63               18.30     Area010          1996      135.3730
# 4          AIR10                 NaN     Area019          1983      112.8016
# ...          ...                 ...         ...           ...           ...
# 1700       KXW10                 NaN     Area027          1983      136.5704
# 1701       CKE54               21.30     Area035          2002       57.0744
# 1702       HAY13               20.40     Area017          2005      182.7422
# 1703       ZEE32               20.00     Area018          2007      266.9672
# 1704       NDL93                8.08     Area045          2000      238.7694
#
# ...

# %%
test
# Out:
#      Medicine_ID  Counterfeit_Weight DistArea_ID  Active_Since  Medicine_MRP  \
# 0          HLZ81                 NaN     Area027          1983       85.5328
# 1          ECE94               13.45     Area045          2000      257.1460
# 2          SAD14                7.10     Area045          2000       98.1172
# 3          EQV63               18.30     Area010          1996      135.3730
# 4          AIR10                 NaN     Area019          1983      112.8016
# ...          ...                 ...         ...           ...           ...
# 1700       KXW10                 NaN     Area027          1983      136.5704
# 1701       CKE54               21.30     Area035          2002       57.0744
# 1702       HAY13               20.40     Area017          2005      182.7422
# 1703       ZEE32               20.00     Area018          2007      266.9672
# 1704       NDL93                8.08     Area045          2000      238.7694
#
# ...

# %%
train
# Out:
#      Medicine_ID  Counterfeit_Weight DistArea_ID  Active_Since  Medicine_MRP  \
# 0          RRA15              13.100     Area046          1995      160.2366
# 1          YVV26                 NaN     Area027          1983      110.4384
# 2          LJC15               9.025     Area046          1995      259.4092
# 3          GWC40              11.800     Area046          1995       99.9830
# 4          QMN13                 NaN     Area019          1983       56.4402
# ...          ...                 ...         ...           ...           ...
# 6813       OYN80               8.535     Area046          1995      204.1452
# 6814       ACW12              20.650     Area046          1995      235.1088
# 6815       OPM10              20.000     Area017          2005      193.6292
# 6816       SLY12              10.180     Area045          2000      162.8682
# 6817       ATT10               7.930     Area018          2007      177.5500
#
# ...

# %%
train.describe()
# Out:
#        Counterfeit_Weight  Active_Since  Medicine_MRP  Availability_rating  \
# count         5652.000000   6818.000000   6818.000000          6818.000000
# mean            14.115057   1995.836316    151.401518             0.079174
# std              4.649668      8.368979     62.203961             0.051481
# min              5.855000   1983.000000     41.790000             0.013000
# 25%              9.995000   1985.000000    104.509400             0.040058
# 50%             13.800000   1997.000000    153.195700             0.066955
# 75%             18.050000   2002.000000    196.148350             0.107697
# max             22.650000   2007.000000    277.188400             0.341391
#
#        Counterfeit_Sales
# count        6818.000000
# mean         2280.583480
# std          1693.354404
# min           146.290000
# 25%           933.265600
# 50%          1902.670400
# 75%          3207.638400
# max         13199.964800

# %%
train.head()
# Out:
#   Medicine_ID  Counterfeit_Weight DistArea_ID  Active_Since  Medicine_MRP  \
# 0       RRA15              13.100     Area046          1995      160.2366
# 1       YVV26                 NaN     Area027          1983      110.4384
# 2       LJC15               9.025     Area046          1995      259.4092
# 3       GWC40              11.800     Area046          1995       99.9830
# 4       QMN13                 NaN     Area019          1983       56.4402
#
#         Medicine_Type SidEffect_Level  Availability_rating  \
# 0        Antimalarial        critical             0.070422
# 1         Mstablizers            mild             0.013000
# 2             Cardiac            mild             0.060783
# 3  OralContraceptives            mild             0.065555
# 4       Hreplacements        critical             0.248859
#
#             Area_Type Area_City_Type Area_dist_level  Counterfeit_Sales
# 0            DownTown         Tier 1           Small          1775.5026
# ...

# %%
train.shape
# Out:
# (6818, 12)

# %%
test.shape
# Out:
# (1705, 11)

# %%
train.columns
# Out:
# Index(['Medicine_ID', 'Counterfeit_Weight', 'DistArea_ID', 'Active_Since',
#        'Medicine_MRP', 'Medicine_Type', 'SidEffect_Level',
#        'Availability_rating', 'Area_Type', 'Area_City_Type', 'Area_dist_level',
#        'Counterfeit_Sales'],
#       dtype='object')

# %%
test.columns
# Out:
# Index(['Medicine_ID', 'Counterfeit_Weight', 'DistArea_ID', 'Active_Since',
#        'Medicine_MRP', 'Medicine_Type', 'SidEffect_Level',
#        'Availability_rating', 'Area_Type', 'Area_City_Type',
#        'Area_dist_level'],
#       dtype='object')

# %%
test['Counterfeit_Sales']=np.nan

# %%
train['data']='train'
test['data']='test'
test=test[train.columns]

# %%
all=pd.concat([train,test],axis=0)
all.head()
# Out:
#   Medicine_ID  Counterfeit_Weight DistArea_ID  Active_Since  Medicine_MRP  \
# 0       RRA15              13.100     Area046          1995      160.2366
# 1       YVV26                 NaN     Area027          1983      110.4384
# 2       LJC15               9.025     Area046          1995      259.4092
# 3       GWC40              11.800     Area046          1995       99.9830
# 4       QMN13                 NaN     Area019          1983       56.4402
#
#         Medicine_Type SidEffect_Level  Availability_rating  \
# 0        Antimalarial        critical             0.070422
# 1         Mstablizers            mild             0.013000
# 2             Cardiac            mild             0.060783
# 3  OralContraceptives            mild             0.065555
# 4       Hreplacements        critical             0.248859
#
#             Area_Type Area_City_Type Area_dist_level  Counterfeit_Sales   data
# 0            DownTown         Tier 1           Small          1775.5026  train
# ...

# %%
all.shape
# Out:
# (8523, 13)

# %%
all.dtypes
# Out:
# Medicine_ID             object
# Counterfeit_Weight     float64
# DistArea_ID             object
# Active_Since             int64
# Medicine_MRP           float64
# Medicine_Type           object
# SidEffect_Level         object
# Availability_rating    float64
# Area_Type               object
# Area_City_Type          object
# Area_dist_level         object
# Counterfeit_Sales      float64
# data                    object
# dtype: object

# %%
all.describe()
# Out:
#        Counterfeit_Weight  Active_Since  Medicine_MRP  Availability_rating  \
# count         7060.000000   8523.000000   8523.000000          8523.000000
# mean            14.157645   1995.831867    151.292782             0.079132
# std              4.643456      8.371760     62.275067             0.051598
# min              5.855000   1983.000000     41.590000             0.013000
# 25%             10.073750   1985.000000    104.126500             0.039989
# 50%             13.900000   1997.000000    153.312800             0.066931
# 75%             18.150000   2002.000000    195.943700             0.107585
# max             22.650000   2007.000000    277.188400             0.341391
#
#        Counterfeit_Sales
# count        6818.000000
# mean         2280.583480
# std          1693.354404
# min           146.290000
# 25%           933.265600
# 50%          1902.670400
# 75%          3207.638400
# max         13199.964800

# %%
all.isnull().sum()
# Out:
# Medicine_ID               0
# Counterfeit_Weight     1463
# DistArea_ID               0
# Active_Since              0
# Medicine_MRP              0
# Medicine_Type             0
# SidEffect_Level           0
# Availability_rating       0
# Area_Type                 0
# Area_City_Type            0
# Area_dist_level           0
# Counterfeit_Sales      1705
# data                      0
# dtype: int64

# %%
for col in all:
    print("*****************************************")
    print("@@@@@@@@@@@@", col,"##########")
    print(all[col].nunique())
    
    print(all[col].unique())
    print(all[col].value_counts())
# Out:
# *****************************************
# @@@@@@@@@@@@ Medicine_ID ##########
# 1557
# ['RRA15' 'YVV26' 'LJC15' ... 'KGC13' 'JTW13' 'OPM10']
# SGZ11    12
# KIS14    10
# ORS21    10
# GVZ23    10
# OQH15     9
#          ..
# FVS71     1
# QGU83     1
# ETU15     1
# YDD11     1
# YYX14     1
# Name: Medicine_ID, Length: 1557, dtype: int64
# *****************************************
# @@@@@@@@@@@@ Counterfeit_Weight ##########
# 415
# [13.1      nan  9.025 11.8    8.775 18.     7.68  18.55   9.51   9.27
#  18.15  13.9   20.3   22.55  13.3   21.65  20.05  15.45  19.05  16.4
#  11.4   20.9   13.4   18.8   22.    11.6   13.6   18.3    8.69  19.65
#   6.335 19.    10.51  22.05  17.65  11.95   9.05  12.1   16.9    7.78
#  18.65   6.785 10.14  16.3   11.1   16.55  10.9   21.55  20.4   19.55
#  12.9    8.625 15.3   10.23  15.1   14.6    7.08  13.45  20.15  16.
#  17.5    8.205 18.05   7.435  7.495  8.57  17.55  15.95  13.95  10.275
# ...

# %%
all.dtypes
# Out:
# Medicine_ID             object
# Counterfeit_Weight     float64
# DistArea_ID             object
# Active_Since             int64
# Medicine_MRP           float64
# Medicine_Type           object
# SidEffect_Level         object
# Availability_rating    float64
# Area_Type               object
# Area_City_Type          object
# Area_dist_level         object
# Counterfeit_Sales      float64
# data                    object
# dtype: object

# %%
all.isnull().sum()
# Out:
# Medicine_ID               0
# Counterfeit_Weight     1463
# DistArea_ID               0
# Active_Since              0
# Medicine_MRP              0
# Medicine_Type             0
# SidEffect_Level           0
# Availability_rating       0
# Area_Type                 0
# Area_City_Type            0
# Area_dist_level           0
# Counterfeit_Sales      1705
# data                      0
# dtype: int64

# %%
all.drop(['Counterfeit_Weight','Medicine_ID'],axis=1, inplace=True)

# %%
all.shape
# Out:
# (8523, 11)

# %%
all['Medicine_MRP']=all['Medicine_MRP'].astype(int)

# %%
all['Availability_rating']=all['Availability_rating'].astype(int)

# %%
for col in ['Counterfeit_Sales']:
    all[col]=pd.to_numeric(all[col],errors='coerce')

# %%
all.dtypes
# Out:
# DistArea_ID                    object
# Active_Since                    int64
# Medicine_MRP                    int32
# Medicine_Type                  object
# Availability_rating             int32
# Area_Type                      object
# Area_City_Type                 object
# Area_dist_level                object
# Counterfeit_Sales             float64
# data                           object
# SidEffect_Level_isCritical      int32
# dtype: object

# %%
all['Availability_rating'].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Availability_rating, dtype: int32

# %%
print(all['Availability_rating'].nunique())
print(all['Availability_rating'].unique())
# Out:
# 1
# [0]

# %%
all.dtypes
# Out:
# DistArea_ID                    object
# Active_Since                    int64
# Medicine_MRP                    int32
# Medicine_Type                  object
# Availability_rating             int32
# Area_Type                      object
# Area_City_Type                 object
# Area_dist_level                object
# Counterfeit_Sales             float64
# data                           object
# SidEffect_Level_isCritical      int32
# dtype: object

# %%
cat_cols=all.select_dtypes(['object']).columns
print(cat_cols)
# Out:
# Index(['DistArea_ID', 'Medicine_Type', 'Area_Type', 'Area_City_Type',
#        'Area_dist_level', 'data'],
#       dtype='object')

# %%
cat_cols=cat_cols[:-1]
print(cat_cols)
# Out:
# Index(['DistArea_ID', 'Medicine_Type', 'Area_Type', 'Area_City_Type',
#        'Area_dist_level'],
#       dtype='object')

# %%
for col in cat_cols:
    print("@@@@@@@@@@@@", col,"##########")
    print(all[col].nunique())
    
    print(all[col].unique())
    print(all[col].value_counts())
# Out:
# @@@@@@@@@@@@ DistArea_ID ##########
# 10
# ['Area046' 'Area027' 'Area019' 'Area045' 'Area018' 'Area013' 'Area017'
#  'Area010' 'Area035' 'Area049']
# Area027    935
# Area013    932
# Area046    930
# Area035    930
# Area049    930
# Area045    929
# Area018    928
# Area017    926
# Area010    555
# Area019    528
# Name: DistArea_ID, dtype: int64
# @@@@@@@@@@@@ Medicine_Type ##########
# 16
# ['Antimalarial' 'Mstablizers' 'Cardiac' 'OralContraceptives'
#  'Hreplacements' 'Antiseptics' 'Statins' 'Analgesics' 'MuscleRelaxants'
#  'Antibiotics' 'Antifungal' 'Antiviral' 'Tranquilizers' 'Antacids'
#  'Antipyretics' 'Stimulants']
# Antibiotics           1232
# Hreplacements         1200
# Antiseptics            910
# OralContraceptives     856
# Antipyretics           682
# Cardiac                649
# Mstablizers            648
# Tranquilizers          520
# Analgesics             445
# Antimalarial           425
# Antacids               251
# Statins                214
# ...

# %%
for col in cat_cols:
    freqs=all[col].value_counts()
    k= freqs.index[freqs>20][:-1]
    for cat in k:
        name=col+'_'+cat 
        all[name]=(all[col]==cat).astype(int)
    del all[col]
    print(col)
# Out:
# DistArea_ID
# Medicine_Type
# Area_Type
# Area_City_Type
# Area_dist_level

# %%
all.dtypes
# Out:
# Active_Since                          int64
# Medicine_MRP                          int32
# Availability_rating                   int32
# Counterfeit_Sales                   float64
# data                                 object
# SidEffect_Level_isCritical            int32
# DistArea_ID_Area027                   int32
# DistArea_ID_Area013                   int32
# DistArea_ID_Area046                   int32
# DistArea_ID_Area035                   int32
# DistArea_ID_Area049                   int32
# DistArea_ID_Area045                   int32
# DistArea_ID_Area018                   int32
# DistArea_ID_Area017                   int32
# DistArea_ID_Area010                   int32
# Medicine_Type_Antibiotics             int32
# Medicine_Type_Hreplacements           int32
# Medicine_Type_Antiseptics             int32
# Medicine_Type_OralContraceptives      int32
# Medicine_Type_Antipyretics            int32
# Medicine_Type_Cardiac                 int32
# ...

# %%
all.shape
# Out:
# (8523, 38)

# %%
all.isnull().sum()
# Out:
# Active_Since                           0
# Medicine_MRP                           0
# Availability_rating                    0
# Counterfeit_Sales                   1705
# data                                   0
# SidEffect_Level_isCritical             0
# DistArea_ID_Area027                    0
# DistArea_ID_Area013                    0
# DistArea_ID_Area046                    0
# DistArea_ID_Area035                    0
# DistArea_ID_Area049                    0
# DistArea_ID_Area045                    0
# DistArea_ID_Area018                    0
# DistArea_ID_Area017                    0
# DistArea_ID_Area010                    0
# Medicine_Type_Antibiotics              0
# Medicine_Type_Hreplacements            0
# Medicine_Type_Antiseptics              0
# Medicine_Type_OralContraceptives       0
# Medicine_Type_Antipyretics             0
# Medicine_Type_Cardiac                  0
# Medicine_Type_Mstablizers              0
# Medicine_Type_Tranquilizers            0
# ...

# %%
#LETS sepearate train and test data

train=all[all['data']=='train']
del train['data']

# %%
test=all[all['data']=='test']
test.drop(['data','Counterfeit_Sales'],axis=1, inplace=True)
# Out:
# C:\Users\gtu\AppData\Local\Temp\ipykernel_844\3436998662.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test.drop(['data','Counterfeit_Sales'],axis=1, inplace=True)

# %%
del all

# %% [markdown]
# # model implementation

# %%
from sklearn.model_selection import train_test_split

# %%
train1,train2=train_test_split(train,test_size=0.2,random_state=2)

# %%
x_train1=train1.drop('Counterfeit_Sales',axis=1)

y_train1=train1['Counterfeit_Sales']

# %%
x_train1.shape
# Out:
# (5454, 36)

# %%
y_train1.shape
# Out:
# (5454,)

# %%
from sklearn.model_selection import train_test_split

# %%
test1,test2=train_test_split(test,train_size=0.2,random_state=2)

# %%
x_test1=test1.drop('Counterfeit_Sales',axis=1)

y_test1=test1('Counterfeit_Sales')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_844\3614758748.py in <module>
# ----> 1 x_test1=test1.drop('Counterfeit_Sales',axis=1)
#       2
#       3 y_test1=test1('Counterfeit_Sales')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ...

# %% [markdown]
# # linear regression

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()

# %%
lm.fit(x_train1,y_train1)
# Out:
# LinearRegression()
